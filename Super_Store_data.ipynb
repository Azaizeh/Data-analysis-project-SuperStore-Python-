# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
df=pd.read_excel('/content/sample_data/Sample - Superstore.xlsx')
df
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
df.describe
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df[['Sales']]
# Out:
#          Sales
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680
# ...        ...
# 9989   25.2480
# 9990   91.9600
# 9991  258.5760
# 9992   29.6000
# 9993  243.1600
#
# [9994 rows x 1 columns]

# %%
df.loc[23]
# Out:
# Row ID                                            24
# Order ID                              US-2019-156909
# Order Date                       2019-07-16 00:00:00
# Ship Date                        2019-07-18 00:00:00
# Ship Mode                               Second Class
# Customer ID                                 SF-20065
# Customer Name                        Sandra Flanagan
# Segment                                     Consumer
# Country/Region                         United States
# City                                    Philadelphia
# State                                   Pennsylvania
# Postal Code                                  19140.0
# Region                                          East
# Product ID                           FUR-CH-10002774
# Category                                   Furniture
# Sub-Category                                  Chairs
# Product Name      Global Deluxe Stacking Chair, Gray
# Sales                                         71.372
# ...

# %%
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False)
# Out:
# Customer Name
# Sean Miller        25043.050
# Tamara Chand       19052.218
# Raymond Buch       15117.339
# Tom Ashbrook       14595.620
# Adrian Barton      14473.571
#                      ...
# Roy Skaria            22.328
# Mitch Gastineau       16.739
# Carl Jackson          16.520
# Lela Donovan           5.304
# Thais Sissman          4.833
# Name: Sales, Length: 793, dtype: float64

# %%
df.groupby('City')['Sales'].sum().sort_values(ascending=False)
# Out:
# City
# New York City    256368.161
# Los Angeles      175851.341
# Seattle          119540.742
# San Francisco    112669.092
# Philadelphia     109077.013
#                     ...
# Ormond Beach          2.808
# Pensacola             2.214
# Jupiter               2.064
# Elyria                1.824
# Abilene               1.392
# Name: Sales, Length: 531, dtype: float64

# %%
df.groupby('Sub-Category')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Binders        5974
# Paper          5178
# Furnishings    3563
# Phones         3289
# Storage        3158
# Art            3000
# Accessories    2976
# Chairs         2356
# Appliances     1729
# Labels         1400
# Tables         1241
# Fasteners       914
# Envelopes       906
# Bookcases       868
# Supplies        647
# Machines        440
# Copiers         234
# Name: Quantity, dtype: int64

# %%
A=df.groupby('Sub-Category')['Discount'].sum().sort_values(ascending=False)
A
# Out:
# Sub-Category
# Binders        567.00
# Phones         137.40
# Furnishings    132.40
# Chairs         105.00
# Paper          102.60
# Tables          83.35
# Appliances      77.60
# Storage         63.20
# Accessories     60.80
# Art             59.60
# Bookcases       48.14
# Machines        35.20
# Labels          25.00
# Envelopes       20.40
# Fasteners       17.80
# Supplies        14.60
# Copiers         11.00
# Name: Discount, dtype: float64

# %%
A.plot()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
B=df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
B
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
df['Lead Time'] = df['Ship Date']-df['Order Date']
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.groupby('City')['Lead time'].max().sort_values(ascending=False)
# Out:
# City
# Nashua       7 days
# Middletown   7 days
# Quincy       7 days
# Miami        7 days
# Raleigh      7 days
#               ...
# Portage      0 days
# Kenner       0 days
# Billings     0 days
# Mentor       0 days
# Rock Hill    0 days
# Name: Lead time, Length: 531, dtype: timedelta64[ns]

# %%
del df["Lead Time"]

# %%
df.groupby('Segment')['Order ID'].count().sort_values(ascending=False)
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Order ID, dtype: int64

# %%
df.groupby('Ship Mode')['Order ID'].count().sort_values(ascending=False)
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Order ID, dtype: int64

# %%
specifc_ShipMode=['Same Day']
m=df[df['Ship Mode'].isin(specifc_ShipMode)]
m.sort_values(by=['Lead Time'],ascending=False)
# Out:
#       Row ID        Order ID Order Date  Ship Date Ship Mode Customer ID  \
# 3440    3441  CA-2017-144099 2017-11-29 2017-11-30  Same Day    PO-19195
# 8769    8770  CA-2018-151148 2018-09-12 2018-09-13  Same Day    PO-19180
# 9004    9005  CA-2017-102855 2017-04-05 2017-04-06  Same Day    JF-15415
# 5886    5887  US-2016-109456 2016-10-16 2016-10-17  Same Day    LS-17245
# 5885    5886  US-2016-109456 2016-10-16 2016-10-17  Same Day    LS-17245
# ...      ...             ...        ...        ...       ...         ...
# 3537    3538  CA-2016-158771 2016-05-09 2016-05-09  Same Day    SB-20290
# 3531    3532  CA-2018-155565 2018-05-28 2018-05-28  Same Day    EH-13765
# 3503    3504  CA-2019-125115 2019-04-10 2019-04-10  Same Day    RD-19930
# 3502    3503  CA-2019-125115 2019-04-10 2019-04-10  Same Day    RD-19930
# 9963    9964  CA-2017-143700 2017-07-26 2017-07-26  Same Day    AS-10240
#
#           Customer Name      Segment Country/Region           City  ...  \
# ...

# %% [markdown]
# We take a specific sub category and study it

# %%
specific_Category=['Phones']
x=df[df['Sub-Category'].isin(specific_Category)]
x.groupby('Product Name')['Profit'].sum().sort_values(ascending=False)
# Out:
# Product Name
# Samsung Galaxy Mega 6.3                                                                                 1822.7566
# Apple iPhone 5                                                                                          1611.5784
# Panasonic KX-TG9471B                                                                                    1168.1004
# Panasonic KX-TG9541B DECT 6.0 Digital 2-Line Expandable Cordless Phone With Digital Answering System    1147.4235
# Samsung Galaxy S4 Mini                                                                                  1104.4765
#                                                                                                           ...
# Cisco IP Phone 7961G-GE VoIP phone                                                                      -119.1190
# Samsung Galaxy Note 2                                                                                   -128.7972
# ...

# %%
specific_Category=['Phones']
x=df[df['Sub-Category'].isin(specific_Category)]
x.groupby('Product Name')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product Name
# I Need's 3d Hello Kitty Hybrid Silicone Case Cover for HTC One X 4g with 3d Hello Kitty Stylus Pen Green/pink    52
# Geemarc AmpliPOWER60                                                                                             46
# Pyle PMP37LED                                                                                                    43
# Motorola HK250 Universal Bluetooth Headset                                                                       41
# Polycom VVX 310 VoIP phone                                                                                       40
#                                                                                                                  ..
# RCA H5401RE1 DECT 6.0 4-Line Cordless Handset With Caller ID/Call Waiting                                         3
# Panasonic Business Telephones KX-T7736                                                                            3
# ...

# %%
specific_Category=['Phones']
x=df[df['Sub-Category'].isin(specific_Category)]
x.groupby('Product Name')['Sales'].sum().sort_values(ascending=False)
# Out:
# Product Name
# Samsung Galaxy Mega 6.3                                                13943.668
# Apple iPhone 5                                                         12996.600
# Wilson Electronics DB Pro Signal Booster                                8878.400
# Mitel MiVoice 5330e IP Phone                                            7699.720
# Samsung Galaxy S III - 16GB - pebble blue (T-Mobile)                    7139.796
#                                                                          ...
# Shocksock Galaxy S4 Armband                                               63.510
# Anker 24W Portable Micro USB Car Charger                                  61.544
# SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x 2.5", Black                56.164
# Sannysis Cute Owl Design Soft Skin Case Cover for Samsung Galaxy S4       13.860
# PNY Rapid USB Car Charger - Black                                          9.588
# Name: Sales, Length: 189, dtype: float64

# %%
k=df[['Sub-Category','Product Name','Profit']]
o=k[k['Profit'] <=0]
o.sort_values(by=['Sub-Category'],ascending=False)
# Out:
#      Sub-Category                                       Product Name    Profit
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table -383.0310
# 5272       Tables  Lesro Sheffield Collection Coffee Table, End T...  -14.9877
# 6104       Tables                 Bevis Boat-Shaped Conference Table  -83.8752
# 5997       Tables  Lesro Round Back Collection Coffee Table, End ... -147.8655
# 5923       Tables                Bevis Oval Conference Table, Walnut -120.0508
# ...           ...                                                ...       ...
# 1614  Accessories                              V7 USB Numeric Keypad  -13.6461
# 1646  Accessories  SanDisk Ultra 32 GB MicroSDHC Class 10 Memory ...   -3.0940
# 3359  Accessories    Logitech Desktop MK120 Mouse and keyboard Combo   -3.2720
# 6477  Accessories                 Logitech P710e Mobile Speakerphone   -2.5749
# 7412  Accessories  SanDisk Ultra 32 GB MicroSDHC Class 10 Memory ...   -3.0940
#
# [1936 rows x 3 columns]

# %% [markdown]
# **Index and multi index**

# %%
df2=df.set_index(['Category','Sub-Category'])
df2.sort_index(ascending=[True,True])
# Out:
#                          Row ID        Order ID Order Date  Ship Date  \
# Category   Sub-Category
# Furniture  Bookcases          1  CA-2018-152156 2018-11-08 2018-11-11
#            Bookcases         28  US-2017-150630 2017-09-17 2017-09-21
#            Bookcases         39  CA-2017-117415 2017-12-27 2017-12-31
#            Bookcases        190  CA-2017-102281 2017-10-12 2017-10-14
#            Bookcases        193  CA-2017-102281 2017-10-12 2017-10-14
# ...                         ...             ...        ...        ...
# Technology Phones          9974  US-2018-103674 2018-12-06 2018-12-10
#            Phones          9977  US-2018-103674 2018-12-06 2018-12-10
#            Phones          9984  US-2018-157728 2018-09-22 2018-09-28
#            Phones          9989  CA-2019-163629 2019-11-17 2019-11-21
#            Phones          9992  CA-2019-121258 2019-02-26 2019-03-03
#
#                               Ship Mode Customer ID    Customer Name  \
# Category   Sub-Category
# ...
